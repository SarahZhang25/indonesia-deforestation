# %%
# !pip install ipympl
# !pip install geopandas

# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import geopandas as gpd
import pandas as pd
import descartes
from shapely.geometry import Polygon
# Out:
# Requirement already satisfied: ipympl in c:\users\szhan\anaconda3\lib\site-packages (0.9.3)
# Requirement already satisfied: pillow in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (9.0.1)
# Requirement already satisfied: ipython-genutils in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: numpy in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (1.21.5)
# Requirement already satisfied: traitlets<6 in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (5.1.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: ipython<9 in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (8.2.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipympl) (3.5.1)
# Requirement already satisfied: stack-data in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: backcall in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: decorator in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.17.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (61.2.0)
# Requirement already satisfied: colorama in c:\users\szhan\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.4.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\szhan\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.9.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\szhan\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\szhan\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\szhan\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\szhan\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\szhan\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\szhan\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\szhan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\szhan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\szhan\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\szhan\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.7.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupyter-core in c:\users\szhan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\szhan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\szhan\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.15.1)
# Requirement already satisfied: wcwidth in c:\users\szhan\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\szhan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\szhan\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.8)
# Requirement already satisfied: pure-eval in c:\users\szhan\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: executing in c:\users\szhan\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\szhan\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\szhan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\szhan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\szhan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (5.2.0)
# Requirement already satisfied: entrypoints in c:\users\szhan\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: pyzmq>=13 in c:\users\szhan\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\szhan\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (302)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\szhan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\szhan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\szhan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\szhan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\szhan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\szhan\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\szhan\anaconda3\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (3.7.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\szhan\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\szhan\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\szhan\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: bleach in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: testpath in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\szhan\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\szhan\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\szhan\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\szhan\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\szhan\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)

# %%
# base layers
#indonesia = gpd.read_file("data/indonesia-provinces.geojson") # low res; source: https://github.com/superpikar/indonesia-geojson/blob/master/indonesia.geojson
indonesia = gpd.read_file("data/indonesia_boundary.json") # high res; source: https://geodata.mit.edu/catalog/stanford-py486tm4357
logging_concessions = gpd.read_file("data/Managed_Forest_Concessions_(WRI).geojson")
oil_palm_concessions = gpd.read_file("data/Greenpeace_Indonesia_Oil_Palm_Concessions_Map_Nov_2020.shp")

# set up plotting
fig = plt.figure()
ax = plt.subplot(111)

# choose more colors here: https://matplotlib.org/stable/gallery/color/named_colors.html
indonesia.plot(ax=ax, color="lightgray", edgecolor = "black", label='Indonesia Land Mass', legend=True) # plot indonesia
logging_concessions.plot(ax=ax, color="limegreen", edgecolor = "darkgreen", alpha=.75, label='Logging Concessions', legend=True) # plot concession regions
oil_palm_concessions.plot(ax=ax, color="crimson", edgecolor = "darkred", alpha=.75, label='Oil Palm Concessions', legend=True) # plot concession regions


# label logging concessions
representative_coords = logging_concessions['geometry'].apply(lambda x: x.representative_point().coords[:])
logging_concessions['coords'] = [coords[0] for coords in representative_coords]
logging_concessions['xcoords'] = [coord[0] for coord in logging_concessions['coords']]
logging_concessions['ycoords'] = [coord[1] for coord in logging_concessions['coords']]

# label with a number index on each concession
#for idx, row in logging_concessions.iterrows():
#     plt.annotate(text=logging_concessions.index[idx], xy=row['coords'],
#                  horizontalalignment='center', fontsize=10, color = "darkgreen")

# label with a dot on each concession
plt.plot(logging_concessions['xcoords'], logging_concessions['ycoords'], 'g.')



# label oil palm concessions
oil_palm_concessions['coords'] = oil_palm_concessions['geometry'].apply(lambda x: x.representative_point().coords[:])
oil_palm_concessions['coords'] = [coords[0] for coords in oil_palm_concessions['coords']]
oil_palm_concessions['xcoords'] = [coord[0] for coord in oil_palm_concessions['coords']]
oil_palm_concessions['ycoords'] = [coord[1] for coord in oil_palm_concessions['coords']]

# label with a number index on each concession
#for idx, row in oil_palm_concessions.iterrows():
#     plt.annotate(text=oil_palm_concessions.index[idx], xy=row['coords'],
#                  horizontalalignment='center', fontsize=10, color = "darkred")
                  
# label with a dot on each concession
plt.plot(oil_palm_concessions['xcoords'], oil_palm_concessions['ycoords'], 'r.')


# legend
lines = [
    Line2D([0], [0], linestyle="none", marker="s", markersize=10, markerfacecolor=t.get_facecolor())
    for t in ax.collections[1:]
]
labels = [t.get_label() for t in ax.collections[1:]]
ax.legend(lines, labels, loc='best')


plt.title("Concessions in Indonesia")                  
plt.xlabel("Latitude")
plt.ylabel("Longitude")
plt.axis('scaled')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
